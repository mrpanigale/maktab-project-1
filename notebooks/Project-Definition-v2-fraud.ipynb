# %% [markdown]
# # First Machine Learning Project
#
# ## Design and Implementation of a Standard Machine Learning Pipeline
# ### Credit Card Fraud Detection Pipeline
# ---
#
# # Project Information
#
# | Item | Description |
# |---|---|
# | Project Title | Credit Card Fraud Detection Pipeline |
# | Document Version | 3.0 |
# | Course Stage | First 8 Weeks of Machine Learning Course |
# | Problem Type | Binary Classification |
# | Reference Dataset | Credit Card Fraud Detection Dataset |
# | Project Type | End-to-End Machine Learning Pipeline |
# | Submission Format | GitHub Repository |
#
# ---

# %% [markdown]
# # 1. Project Overview
#
# In this project, you will work as a **Junior Machine Learning Engineer** and design an end-to-end machine learning pipeline.
#
# The goal is to implement a complete workflow starting from raw data ingestion and preprocessing, continuing through model training and evaluation, and finally delivering a prediction component that can be used for new samples.
#
# The main focus of this project is not only **achieving a high prediction score**, but also **understanding and implementing a reliable machine learning development process**.
#
# You will practice:
#
# - Designing a complete Machine Learning Pipeline
# - Preparing and analyzing real-world data
# - Avoiding common ML mistakes such as Data Leakage
# - Comparing different machine learning algorithms
# - Performing controlled experiments
# - Evaluating and selecting the best model
# - Building a reusable prediction module
#
# ---

# %% [markdown]
# # 2. Learning Outcomes
#
# After successfully completing this project, you should be able to:
#
# ## 2.1 Design a Machine Learning Pipeline
#
# Transform a raw dataset into a structured ML workflow:
#
# ```
#
# Raw Data
# |
# v
# Data Preparation
# |
# v
# Train/Test Split
# |
# v
# Feature Scaling
# |
# v
# Model Training
# |
# v
# Evaluation
# |
# v
# Prediction
#
# ```
#
# ---
#
# ## 2.2 Perform Data Preparation Correctly
#
# You should be able to:
#
# - Load datasets using Pandas
# - Analyze dataset structure
# - Calculate descriptive statistics
# - Handle missing values
# - Prepare features for machine learning
# - Prevent Data Leakage
#
# ---
#
# ## 2.3 Train and Evaluate Machine Learning Models
#
# You should be able to:
#
# - Train multiple ML algorithms
# - Compare model performance
# - Select an appropriate final model
# - Explain your engineering decisions
#
# ---
#
# ## 2.4 Conduct Scientific Experiments
#
# You should be able to:
#
# - Form hypotheses before experiments
# - Design controlled experiments
# - Analyze the impact of different decisions
# - Interpret model behavior
#
#
# ## 2.5 Handle Class Imbalance
#
# You should be able to:
#
# - Identify class imbalance in a classification dataset
# - Understand why Accuracy can be misleading on imbalanced data
# - Analyze Precision, Recall, and F1-score
# - Interpret False Positives and False Negatives
# - Select appropriate evaluation metrics based on the problem requirements
#
# ---

# %% [markdown]
# # 3. Problem Scenario
#
# Credit card fraud is a major challenge for financial institutions.
#
# A bank or payment service provider wants to develop a machine learning system that can identify potentially fraudulent credit card transactions.
#
# Your task is to build an end-to-end machine learning pipeline that predicts whether a transaction is fraudulent.
#
# The model should classify each transaction into one of two classes:
#
# ```text
#
# 0 → Legitimate Transaction
#
# 1 → Fraudulent Transaction
#
# ```
# The main challenge is that fraudulent transactions are much less frequent than legitimate transactions.
#
# Therefore, achieving high Accuracy alone is not sufficient.
#
# Your goal is to build a model that can reliably detect fraudulent transactions while carefully analyzing the trade-off between:
#
# - False Positives
# - False Negatives
# - Precision
# - Recall
# - F1-score
#
# ---
#
#
# # 4. Dataset Description
#
# ## Credit Card Fraud Detection Dataset
#
# Source:
#
# https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
#
# The dataset contains credit card transactions made by European cardholders.
#
# The goal is to identify fraudulent transactions using machine learning.
#
# ### Dataset Characteristics
#
# | Property | Value |
# |---|---|
# | Number of Samples | 284,807 |
# | Number of Features | 30 Features |
# | Target | Class |
# | Problem Type | Binary Classification |
# | Fraudulent Transactions | 492 |
# | Legitimate Transactions | 284,315 |
# | Fraud Ratio | ~0.17% |
#
# ### Target Variable
#
# The `Class` column is the target variable:
#
# ```text
# 0 → Legitimate Transaction
# 1 → Fraudulent Transaction
# ```
#
# The dataset contains:
#
# - Time
# - V1 to V28
# - Amount
#
# **Features**
#
# The features V1 to V28 are anonymized numerical features resulting from a transformation of the original transaction data.
#
# Because these features are anonymized, the focus of this project is on:
#
# - Data analysis
# - Classification
# - Class imbalance
# - Model evaluation
# - Experimentation
# - Reliable fraud detection
#
#
# ---

# %% [markdown]
# # 5. Project Structure
#
# Your GitHub repository should follow this structure:
#
# ```
#
# mini-project-01/
# │
# ├── README.md
# ├── requirements.txt
# ├── .gitignore
# │
# ├── data/
# │   └── creditcard.csv
# │
# ├── src/
# │   ├── data_prep.py
# │   ├── train.py
# │   └── predict.py
# │
# ├── models/
# │   ├── model.pkl
# │   └── scaler.pkl
# │
# └── reports/
#     └── experiments.md
# ```
#
# ---

# %% [markdown]
# # 6. Project Requirements
#
# ## Phase 1: Data Preparation
#
# You must:
#
# - Load the dataset
# - Analyze dataset structure
# - Generate descriptive statistics
# - Check missing values
# - Analyze class distribution
#
#
# Example:
#
# ```
#
# Number of Samples:
# Number of Features:
# Class Distribution:
# Missing Values:
#
# ```
#
# ---
#
# # Phase 2: Data Preprocessing
#
# You must correctly perform:
#
# - Data quality checks
# - Missing value analysis
# - Duplicate analysis
# - Train/Test Split
# - Feature Scaling
#
# Because this is an imbalanced classification problem, use a stratified train/test split.
#
# For example:
#
# ```python
# train_test_split(
#     X,
#     y,
#     test_size=0.2,
#     stratify=y,
#     random_state=42
# )
#
# ## Important Rule: Avoid Data Leakage
#
# The following approach is incorrect:
#
# ```
#
# Scaling
# |
# Train/Test Split
#
# ```
#
#
# Because information from the test set is used during preprocessing.
#
#
# The correct approach:
#
# ```
#
# Train/Test Split
# |
# v
# Fit Scaler on Training Data
# |
# v
# Transform Train and Test Data
#
# ```
#
# ---
#
# # Phase 3: Model Training
#
# You must implement and compare at least three models:
#
# ---
#
# ## Model 1: Logistic Regression
#
# Purpose:
#
# - Establish a simple classification baseline.
# - Analyze the behavior of a linear classifier on an imbalanced dataset.
# ---
#
# ## Model 2: K-Nearest Neighbor (KNN)
#
# Purpose:
#
# - Analyze distance-based learning.
# - Study the impact of feature scaling.
#
# ---
#
# ## Model 3: Decision Tree Classifier
#
# Purpose:
#
# - Explore nonlinear decision boundaries.
# - Analyze overfitting behavior.
# - Investigate the impact of class imbalance.
#
#
# ## Model 4 (Bonus): Simple MLP / Neural Network (PyTorch or TensorFlow / Keras)
#
# Purpose:
#
# - Explore nonlinear decision boundaries.
# - Analyze overfitting behavior.
#
# ---

# %% [markdown]
# # 7. Hypothesis Before Modeling
#
# Before training your models, write your hypotheses in `README.md`.
#
# ### Guiding Questions
#
# 1. Which model do you expect to perform best for fraud detection? Why?
#
# 2. Which metric is more important for this problem: Precision, Recall, or F1-score? Why?
#
# 3. What do you expect to happen if the model predicts all transactions as legitimate?
#
# 4. Do you expect feature scaling to significantly affect KNN performance?
#
# 5. Do you expect the Decision Tree to overfit? Why?
#
# ### Example Hypothesis
#
# > I expect Logistic Regression to provide a strong baseline because the problem is binary classification. However, I expect the Decision Tree to capture nonlinear relationships that Logistic Regression may miss.
#
# > I expect Recall to be particularly important because failing to detect a fraudulent transaction can have a significant cost. However, maximizing Recall alone may produce too many false alarms, so Precision and F1-score should also be considered.
#
# ### After Training Analysis
#
# Explain in your `README.md`:
#
# - Was your initial hypothesis correct?
# - Which model performed best?
# - Which metric was most informative?
# - How did class imbalance affect the results?
# - What was the trade-off between False Positives and False Negatives?

# %% [markdown]
# # 8. Model Evaluation
#
# Because this dataset is highly imbalanced, Accuracy must not be used as the primary metric.
#
# For each model, report:
#
# - Accuracy
# - Precision
# - Recall
# - F1-score
#
# Also report:
#
# - Confusion Matrix
#
# Pay particular attention to:
#
# - False Positives
# - False Negatives
# - Fraud Recall
# - Fraud Precision
#
# ## Required Question
#
# Explain:
#
# > Why can a model achieve very high Accuracy while still being a poor fraud detection system?
# ---
#
# # 9. Cross Validation
#
# You must apply:
#
# 5-Fold Stratified Cross Validation
#
# Because the dataset is highly imbalanced, use stratification to preserve the class distribution across folds.
#
# Evaluate at least:
#
# - Precision
# - Recall
# - F1-score
#
# Report results:
#
# | Model | Mean Precision | Mean Recall | Mean F1 |
# |---|---:|---:|---:|
# | Logistic Regression | | | |
# | KNN | | | |
# | Decision Tree | | | |
#
#
# ---

# %% [markdown]
# # 10. Mandatory Experiment 1: Effect of Scaling
#
# The goal is to understand how feature scaling affects model performance.
#
#
# At minimum, perform this experiment with KNN:
#
# | Model | Scaling | Precision | Recall | F1 |
# |---|---|---:|---:|---:|
# | KNN | Without Scaling | | | |
# | KNN | With Scaling | | | |
#
#
# Explain:
#
# - Why is KNN sensitive to scaling?
# - Why is Decision Tree less sensitive?
#
# ---

# %% [markdown]
# # 11. Mandatory Experiment 2: Hyperparameter Analysis
#
# Perform at least one hyperparameter experiment.
#
# Choose one:
#
#
# ## Option 1: KNN
#
# Compare:
#
# ```
#
# K = 1
# K = 5
# K = 20
#
# ```
#
#
# OR
#
#
# ## Option 2: Decision Tree
#
# Compare:
#
# ```
#
# max_depth = 2
# max_depth = 5
# max_depth = 10
# max_depth = None
#
# ````
#
#
# Report:
#
# | Parameter Value | Precision / Recall / F1 |
# |-|-|
# | | |
#
#
# Analyze:
#
# - Did overfitting occur?
# - Which value provides the best balance?
#
# ---

# %% [markdown]
# # 12. Mandatory Experiment 3: Impact of Classification Threshold
#
# Most classification models use a default decision threshold of 0.5.
#
# Investigate how changing the classification threshold affects fraud detection.
#
# Compare at least three thresholds:
#
# ```text
# 0.3
# 0.5
# 0.7
# ```
#
# | Threshold | Precision | Recall | F1 |
# | --------: | --------: | -----: | -: |
# |       0.3 |           |        |    |
# |       0.5 |           |        |    |
# |       0.7 |           |        |    |
#
#
#
#
# Explain:
#
# - What happens to Recall when the threshold decreases?
# - What happens to Precision?
# - Which threshold would you recommend for a fraud detection system?
# - What trade-off does your chosen threshold create?

# %% [markdown]
# ### چرا این را اضافه می‌کنم؟
#
#
# # 13. Final Model Selection
#
# You must:
#
# 1. Select one final model.
# 2. Select an appropriate classification threshold.
# 3. Explain your decisions.
#
# Your explanation should consider:
#
# - Precision
# - Recall
# - F1-score
# - Confusion Matrix
# - Cross-validation results
# - Class imbalance
# - Overfitting behavior
# - False Positive / False Negative trade-off
# - Problem requirements
# ---

# %% [markdown]
# # 14. Prediction Script (predict.py)
#
# You must implement a script that:
#
# - Loads the trained model
# - Receives input data in JSON format
# - Performs prediction
# - Returns JSON output
#
#
# Example input:
#
# `input.json`
#
# ```json
# {
#   "Time": 406,
#   "V1": -1.359807,
#   "V2": -0.072781,
#   "V3": 2.536347,
#   "V4": 1.378155,
#   "V5": -0.338321,
#   "V6": 0.462388,
#   "V7": 0.239599,
#   "V8": 0.098698,
#   "V9": 0.363787,
#   "V10": 0.090794,
#   "V11": -0.551600,
#   "V12": -0.617801,
#   "V13": -0.991390,
#   "V14": -0.311169,
#   "V15": 1.468177,
#   "V16": -0.470401,
#   "V17": 0.207971,
#   "V18": 0.025791,
#   "V19": 0.403993,
#   "V20": 0.251412,
#   "V21": -0.018307,
#   "V22": 0.277838,
#   "V23": -0.110474,
#   "V24": 0.066928,
#   "V25": 0.128539,
#   "V26": -0.189115,
#   "V27": 0.133558,
#   "V28": -0.021053,
#   "Amount": 149.62
# }
# ````
#
# Note:
#
# The real input file must contain all features required by your final model.
#
# ---
#
# Example output:
#
# `output.json`
#
# ```json
# {
#   "prediction": "Fraud",
#   "class_id": 1,
#   "probability": 0.87,
#   "threshold": 0.5,
#   "status": "success"
# }
# ```
#
# ---

# %% [markdown]
# # 15. Model Saving
#
# Your final model must be saved.
#
#
# ```
# models/model.pkl
# models/encoder.pkl
# models/scaler.pkl
# ```
#
#
# The prediction pipeline must use the same preprocessing logic used during training.
#
# ---

# %% [markdown]
# # 16. Optional Extension: FastAPI Prediction Service
#
# Advanced students may convert their prediction script into a REST API.
#
# Example endpoint:
#
# ```
# POST /predict
# ```
#
# Input:
#
# ```json
# {
#   "Time": 406,
#   "V1": -1.359807,
#   "V2": -0.072781,
#   "V3": 2.536347,
#   "V4": 1.378155,
#   "V5": -0.338321,
#   "V6": 0.462388,
#   "V7": 0.239599,
#   "V8": 0.098698,
#   "V9": 0.363787,
#   "V10": 0.090794,
#   "V11": -0.551600,
#   "V12": -0.617801,
#   "V13": -0.991390,
#   "V14": -0.311169,
#   "V15": 1.468177,
#   "V16": -0.470401,
#   "V17": 0.207971,
#   "V18": 0.025791,
#   "V19": 0.403993,
#   "V20": 0.251412,
#   "V21": -0.018307,
#   "V22": 0.277838,
#   "V23": -0.110474,
#   "V24": 0.066928,
#   "V25": 0.128539,
#   "V26": -0.189115,
#   "V27": 0.133558,
#   "V28": -0.021053,
#   "Amount": 149.62
# }
# ```
#
# Output:
#
# ```json
# {
#   "prediction": "Fraud",
#   "class_id": 1,
#   "probability": 0.87,
#   "threshold": 0.5,
#   "status": "success"
# }
# ```
#
# This section is optional and provides bonus points.
#
# ---

# %% [markdown]
# # 16. README.md Requirements
#
# Your README file must include:
#
# ## 1. Problem Description
#
# Explain:
#
# * Business scenario
# * Objective
# * Dataset
#
# ## 2. Data Analysis
#
# Include:
#
# * Dataset statistics
# * Feature information
# * Missing value analysis
#
# ## 3. Initial Hypothesis
#
# Explain your expected model behavior.
#
# ## 4. Model Comparison
#
# Include:
#
# * Models
# * Metrics
# * Cross-validation results
#
# ## 5. Scaling Experiment
#
# Explain the effect of scaling.
#
# ## 6. Hyperparameter Experiment
#
# Explain the impact of parameter changes.
#
# ## 7. Final Model Selection
#
# Explain why your final model was selected.
#
# ## 8. Running Instructions
#
# Explain:
#
# * Installation
# * Training
# * Prediction
#
# ## 9. Reflection
#
# Answer the questions below.
#
# ---

# %% [markdown]
# # 18. Reflection Questions
#
# ### Question 1
#
# Why is Accuracy a misleading metric for this dataset?
#
# ---
#
# ### Question 2
#
# What is the trade-off between detecting more fraudulent transactions and generating more false alarms?
#
# ---
#
# ### Question 3
#
# If you had one additional week, what would you improve in your fraud detection system?
#
#
# ---

# %% [markdown]
# # 19. Submission Checklist
#
# Before submission, verify:
#
# - [ ] GitHub repository created
# - [ ] requirements.txt included
# - [ ] Data Leakage avoided
# - [ ] Stratified Train/Test Split used
# - [ ] Class imbalance analyzed
# - [ ] Three models implemented
# - [ ] Accuracy reported
# - [ ] Precision reported
# - [ ] Recall reported
# - [ ] F1-score reported
# - [ ] Confusion Matrix included
# - [ ] 5-Fold Stratified Cross Validation completed
# - [ ] Scaling experiment completed
# - [ ] Hyperparameter experiment completed
# - [ ] Classification Threshold experiment completed
# - [ ] Final model selected
# - [ ] Final threshold selected
# - [ ] Final model saved
# - [ ] predict.py works correctly
# - [ ] README is complete
# - [ ] Business interpretation included
# ---
#
# # Good Luck 🚀
#
# ```
